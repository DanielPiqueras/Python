# %% [markdown]
# #Junto a este notebook se incluye un fichero con el contenido del libro "La Isla del Tesoro" en inglés. Lee el fichero y extrae las 30 palabras más frecuentes de todo el libro.
#
# import re
#
# from collections import Counter
#
# """
# f = open('isla.txt', 'r')
# f.seek(0, 0)
# f.tell()
# for line in f:
#     print(line, end='')
#
# with open('isla.txt', 'r') as f:
#
#     pass
# f.closed
# """
#
# """
# with open('texto.txt', 'r') as f:
#     mylist = list(f)
#
#     contador = Counter(mylist)
#
#     palabra_frecuente = contador.most_common()[0][0]
#
#     print("La palabra más frecuente es: ", palabra_frecuente)
# """
#
#
# with open('isla.txt') as f:
#
#     palabras = f.read().split()
#
#     contador = Counter(palabras)
#
#     palabra_frecuente = contador.most_common()[2][0]
#
#     print("La palabra más frecuente es: ", palabra_frecuente)
#
# """
# words = re.findall(r'\w+', open('isla.txt').read().lower())
# print(words)
# """

# %%
#Junto a este notebook se incluye un fichero con el contenido del libro "La Isla del Tesoro" en inglés. Lee el fichero y extrae las 30 palabras más frecuentes de todo el libro.

import re

from collections import Counter

""" f = open('isla.txt', 'r') f.seek(0, 0) f.tell() for line in f: print(line, end='')

with open('isla.txt', 'r') as f:

pass
f.closed """

""" with open('texto.txt', 'r') as f: mylist = list(f)

contador = Counter(mylist)

palabra_frecuente = contador.most_common()[0][0]

print("La palabra más frecuente es: ", palabra_frecuente)
"""

with open('isla.txt') as f:

    palabras = f.read().split()

    contador = Counter(palabras)

    palabra_frecuente = contador.most_common(30)

    for p in range(len(palabra_frecuente)):
        p+=1
        posicion = f'La {p} palabra '
        p-=1
        palabra = f'más frecuente es "{palabra_frecuente[p][0]}"'  
        print(posicion + palabra)
        pass
# Out:
# La 1 palabra más frecuente es "the"
# La 2 palabra más frecuente es "and"
# La 3 palabra más frecuente es "a"
# La 4 palabra más frecuente es "to"
# La 5 palabra más frecuente es "of"
# La 6 palabra más frecuente es "I"
# La 7 palabra más frecuente es "was"
# La 8 palabra más frecuente es "his"
# La 9 palabra más frecuente es "he"
# La 10 palabra más frecuente es "in"
# La 11 palabra más frecuente es "that"
# La 12 palabra más frecuente es "as"
# La 13 palabra más frecuente es "with"
# La 14 palabra más frecuente es "had"
# La 15 palabra más frecuente es "for"
# La 16 palabra más frecuente es "my"
# La 17 palabra más frecuente es "on"
# La 18 palabra más frecuente es "you"
# La 19 palabra más frecuente es "at"
# La 20 palabra más frecuente es "it"
# La 21 palabra más frecuente es "said"
# La 22 palabra más frecuente es "but"
# La 23 palabra más frecuente es "ï¿½"
# La 24 palabra más frecuente es "him"
# La 25 palabra más frecuente es "have"
# La 26 palabra más frecuente es "we"
# La 27 palabra más frecuente es "me"
# La 28 palabra más frecuente es "not"
# La 29 palabra más frecuente es "were"
# La 30 palabra más frecuente es "one"

# %%
"""
Títulos de los capítulos
Teniendo en cuenta que en el libro anterior, los cápitulos siempre están de la siguiente forma:

{numero del capítulo}\n
\n
{titulo del capítulo}
Muestra una lista con todos los títulos y números de los capítulos de "La Isla del Tesoro".
"""
            
with open('isla.txt') as f:
    
    lineas = f.read().split('\n')
    
    for l in range(len(lineas)):
        if(lineas[l].find("CHAPTER")) == 0:
            capitulo = lineas[l]
            
            salto_linea = l+2
            
            nombre_capitulo = lineas[salto_linea]
            
            print(f'El nombre del capítulo {capitulo} es:\n {nombre_capitulo}')
        pass
# Out:
# El nombre del capítulo CHAPTER I es:
#  THE OLD SEA-DOG AT THE ADMIRAL BENBOW
# El nombre del capítulo CHAPTER II  es:
#  BLACK DOG APPEARS AND DISAPPEARS
# El nombre del capítulo CHAPTER III  es:
#  THE BLACK SPOT
# El nombre del capítulo CHAPTER IV  es:
#  THE SEA-CHEST
# El nombre del capítulo CHAPTER V  es:
#  THE LAST OF THE BLIND MAN
# El nombre del capítulo CHAPTER VI  es:
#  THE CAPTAIN S PAFERS

# %%
import json

"""
PRUEBAS

json_file = open('json.txt')
json_content = json_file.read()
loads = json.loads(json_content)
print(loads, type(loads))

#Comprobación de diccionario:
for l in loads['office']['medical']:
    print(f'El número de la habitación es: {l["room-number"]} y el precio del parking es {loads["office"]["parking"]["price"]}')
"""

class Json:
    def __init__(self, texto):
        self.__texto = texto
        self.__loads = ""

    def transformar_diccionario(self):
        json_file = open(self.__texto)
        json_content = json_file.read()
        loads = json.loads(json_content)
        self.__loads = loads
        return loads
        pass

    def nuevo_contenido(self, contenido):
        self.__loads['user']['messages'].append(contenido)
        with open(self.__texto, 'w') as archivo:
            json.dump(self.__loads, archivo)
        pass


texto = Json('json_ejercicio.txt')

diccionario = texto.transformar_diccionario()
texto.nuevo_contenido('Este es el tercer mensaje')
print(diccionario)

# %%
#MENSAJE BROADCAST
import uuid
import random

listado_usuarios = []
usuarios_creados = {}
mensajes_creados = []

class Usuario:    
    def __init__(self, nombre):
        self.nombre = nombre
        self.__id = ""
        self.bandeja = []

    def set_id(self, id):
        self.__id = id

    def get_id(self):
        return self.__id

    def set_bandeja(self, mensajes):
         self.bandeja.append(mensajes)

    def get_bandeja(self):
        return self.bandeja

    def mostrar_mensaje(self):
        if len(self.bandeja) == 0:
            print("No se han encontrado mensajes en este usuario aún.")
        for b in range(len(self.bandeja)):
            if self.bandeja[b]['recibido']:
                if self.bandeja[b]['leido']:
                    print(f"({b}) {self.bandeja[b]['mensaje'].cuerpo} ya ha sido leído.")
                else:
                    print(f"({b}) {self.bandeja[b]['mensaje'].cuerpo}.")

    def marcar_leido(self, numero):
        if self.bandeja[numero]['recibido']:
            self.bandeja[numero]['leido'] = True




class Mensaje_Broadcast:
    def __init__(self, cuerpo):
        self.cuerpo = cuerpo
        self.__id = ""

    def set_id(self, id):
        self.__id = id

    def get_id(self):
        return self.__id

    def mostrar_usuarios_enviados(self, listado):
        for usuarios in listado:
            for mensaje in listado[usuarios].bandeja:
                if mensaje['mensaje'].cuerpo == self.cuerpo:
                    print(f"El mensaje {mensaje['mensaje'].cuerpo} ha sido enviado a {listado[usuarios].nombre}")
        pass

    #Comprobar usuarios leídos manera corta, cambiar nombre de función
    def mostrar_usuarios_leidos(self, listado):
        for usuarios in listado:
            for mensaje in listado[usuarios].bandeja:
                if mensaje['recibido']:
                    if mensaje['leido'] == True and mensaje['mensaje'].cuerpo == self.cuerpo:
                        print(f"El mensaje {mensaje['mensaje'].cuerpo} ha sido leído por {listado[usuarios].nombre}")
        pass

    def mostrar_usuarios_recibidos(self, listado):
        for usuarios in listado:
            for mensaje in listado[usuarios].bandeja:
                if mensaje['recibido'] == True and mensaje['mensaje'].cuerpo == self.cuerpo:
                    print(f"El mensaje {mensaje['mensaje'].cuerpo} ha sido recibido por el usuario {listado[usuarios].nombre}")

    def estadisticas_apertura(self, listado):
        total = 0
        contador = 0
        for usuarios in listado:
            for mensaje in listado[usuarios].bandeja:
                if mensaje['mensaje'].cuerpo == self.cuerpo:
                    total += 1
                if mensaje['leido'] == True and mensaje['mensaje'].cuerpo == self.cuerpo:
                    contador +=1
        print(f'({total}/{contador}) El porcentaje de apertura del mensaje {self.cuerpo} es {str(round((100 * contador)/total,2))}%')    

    def estadisticas_recepcion(self, listado):
        total = 0
        contador = 0
        for usuarios in listado:
            for mensaje in listado[usuarios].bandeja:
                if mensaje['mensaje'].cuerpo == self.cuerpo:
                    total += 1
                if mensaje['recibido'] == True and mensaje['mensaje'].cuerpo == self.cuerpo:
                    contador +=1
        print(f'({total}/{contador}) El porcentaje de recepcion del mensaje {self.cuerpo} es {str(round((100 * contador)/total,2))}%')


class Sistema_Entrega_Mensajes:

    def mostrar_mensajes(self, mensajes):
        for i in range(len(mensajes)):
            print(f'({i}) {mensajes[i].cuerpo}\n')

    def registro_usuarios(self, usuarios):
        for usuario in usuarios:
            usuarios[usuario].set_id(uuid.uuid1())
            
    def anyadir_mensajes(self, usuarios, mensaje):
        
        for usuario in usuarios:
            mensaje.set_id(uuid.uuid1())
            mensajes = {}
            mensajes['mensaje'] = mensaje

            mensajes['leido'] = False
            #Para que un mensaje tenga la posibilidad de no recibirse
            if random.randint(1, 10) > 2:
                mensajes['recibido'] = True

                usuarios[usuario].set_bandeja(mensajes)
            else:
                mensajes['recibido'] = False

                usuarios[usuario].set_bandeja(mensajes)



def menu_principal():
    print("Introduce una opción:\n(0.Salir ---- 1.Usuarios ---- 2.Mensajes)")
    opcion = input()
    return opcion

def menu_usuarios():
    print("Introduce una opción:\n(0.Salir ---- 1.Crear Usuario ---- 2.Mostrar Bandeja de Entrada ---- 3.Marcar Leído)")
    opcion = input()
    return opcion




def inicio():
    print("Introduce una opción:\n(0.Salir ---- 1.Usuarios ---- 2.Mensajes)")
    opcion1 = input()
    while opcion1 != '0':
        if opcion1 == '1':
            usuario()
        elif opcion1 == '2':
            mensaje()
        else:
            print("Incorrecto, vuelve a introducir una opción:\n(0.Salir ---- 1.Usuarios ---- 2.Mensajes)")
            opcion1 = input()
        break

def usuario():
    print("¡¡Bienvenido a los usuarios!!, ¿Qué desea hacer?...\n(0.Atrás ---- 1.Crear Usuario ---- 2.Mostrar Bandeja de Entrada ---- 3.Marcar Leído)")
    opcion_usuario = input()
    while opcion_usuario != '0':

        #Crear Usuario
        if opcion_usuario == '1':
            print("Introduce el nombre de usuario: ")
            nombre_usuario = input("Nombre: ")
            print("Creando usuarios, esto puede tardar un tiempo...")
            usuarios_creados[nombre_usuario] = Usuario(nombre_usuario)
            print(f'Bienvenido {usuarios_creados[nombre_usuario].nombre}!!')
            print("Usuario creado correctamente\n(0.Atrás ---- 1.Crear Usuario ---- 2.Mostrar Bandeja de Entrada ---- 3.Marcar Leído).")
            opcion_usuario = input()

        #Mostrar Bandeja de Entrada
        elif opcion_usuario == '2':
            print("Introduce el nombre de usuario del que quieres ver la bandeja de entrada: ")
            nombre_usuario = input("Nombre: ")
            print("Mostrando la bandeja de entrada...")
            try:
                usuarios_creados[nombre_usuario].mostrar_mensaje()
            except KeyError:
                print("No se ha encontrado el usuario.")
            print("\n(0.Atrás ---- 1.Crear Usuario ---- 2.Mostrar Bandeja de Entrada ---- 3.Marcar Leído).")
            opcion_usuario = input()

        #Marcar leído
        elif opcion_usuario == '3':
            print("Introduce un nombre de usuario")
            nombre_usuario = input("Nombre: ")

            try:
                usuarios_creados[nombre_usuario].mostrar_mensaje()

                try:
                    print("Introduce un mensaje que quieras marcar como leído: ")          
                    mensaje_elegido = input("Tiene que ser un número entero:")

                    usuarios_creados[nombre_usuario].marcar_leido(int(mensaje_elegido))
                    print("Mensaje marcado como leído correctamente\n(0.Atrás ---- 1.Crear Usuario ---- 2.Mostrar Bandeja de Entrada ---- 3.Marcar Leído).")
                except IndexError:
                    print("No se ha encontrado el mensaje")
            except KeyError:
                print("No se ha encontrado el usuario.")
                print("Ha ocurrido un error\n(0.Atrás ---- 1.Crear Usuario ---- 2.Mostrar Bandeja de Entrada ---- 3.Marcar Leído).")
            opcion_usuario = input()

        else:
            print("Incorrecto, vuelve a introducir una opción:\n(0.Atrás ---- 1.Crear Usuario ---- 2.Mostrar Bandeja de Entrada ---- 3.Marcar Leído)")
            opcion_usuario = input()
    inicio()

def mensaje():
    print("¡¡Bienvenido a los mensajes!!, ¿Qué desea hacer?...\n(0.Atrás ---- 1.Crear Mensaje ---- 2.Enviar mensaje ---- 3.Lista de mensajes enviados ---- 4.Lista de mensajes recibidos ---- 5. Lista de mensajes abiertos ---- 6.Obtener estadísticas.)")
    opcion_mensaje = input()
    while opcion_mensaje != '0':
        #Crear mensaje
        if opcion_mensaje == '1':
            print("Introduce el mensaje que desea escribir: ")
            nombre_mensaje = input("Mensaje: ")
            mensajes_creados.append(Mensaje_Broadcast(nombre_mensaje))

            print("Mensaje escrito correctamente\n(0.Atrás ---- 1.Crear Mensaje ---- 2.Enviar mensaje ---- 3.Lista de mensajes enviados ---- 4.Lista de mensajes recibidos ---- 5. Lista de mensajes abiertos ---- 6.Obtener estadísticas).")
            opcion_mensaje = input()
        
        #Enviar mensaje
        elif opcion_mensaje == '2':
            print("Seleccione el mensaje que desea enviar: ")
            SE = Sistema_Entrega_Mensajes()
            SE.mostrar_mensajes(mensajes_creados)
            mensaje_elegido = int(input("Tiene que ser un número entero:"))

            print("Registrando usuarios en la terminal...")
            SE.registro_usuarios(usuarios_creados)

            print("Enviando mensaje...")
            try:
                SE.anyadir_mensajes(usuarios_creados, mensajes_creados[mensaje_elegido])
                print("¡¡Mensaje enviado correctamente!!\n(0.Atrás ---- 1.Crear Mensaje ---- 2.Enviar mensaje ---- 3.Lista de mensajes enviados ---- 4.Lista de mensajes recibidos ---- 5. Lista de mensajes abiertos ---- 6.Obtener estadísticas).")
            except (IndexError, KeyError):
                print("Ha ocurrido un error")
                print("\n(0.Atrás ---- 1.Crear Mensaje ---- 2.Enviar mensaje ---- 3.Lista de mensajes enviados ---- 4.Lista de mensajes recibidos ---- 5. Lista de mensajes abiertos ---- 6.Obtener estadísticas).")
            opcion_mensaje = input()
        
        
        #Listado de mensajes enviados
        elif opcion_mensaje == '3':
            print("Seleccione el mensaje del que desea ver la lista de usuarios a los que se les ha enviado: ")
            #Mejor poner el "SE" inicial arriba
            SE = Sistema_Entrega_Mensajes()
            SE.mostrar_mensajes(mensajes_creados)
            mensaje_elegido = input("Tiene que ser un número entero:")

            try:
                mensajes_creados[int(mensaje_elegido)].mostrar_usuarios_enviados(usuarios_creados)
                print("\n(0.Atrás ---- 1.Crear Mensaje ---- 2.Enviar mensaje ---- 3.Lista de mensajes enviados ---- 4.Lista de mensajes recibidos ---- 5. Lista de mensajes abiertos ---- 6.Obtener estadísticas).")
            except (IndexError, KeyError):
                print("Ha ocurrido un error")
                print("\n(0.Atrás ---- 1.Crear Mensaje ---- 2.Enviar mensaje ---- 3.Lista de mensajes enviados ---- 4.Lista de mensajes recibidos ---- 5. Lista de mensajes abiertos ---- 6.Obtener estadísticas).")
            
            opcion_mensaje = input()
        
        #Listado de mensajes recibidos
        elif opcion_mensaje == '4':
            print("Seleccione el mensaje del que desea ver la lista de usuarios que han recibido el mensaje: ")
            #Mejor poner el "SE" inicial arriba
            SE = Sistema_Entrega_Mensajes()
            SE.mostrar_mensajes(mensajes_creados)
            mensaje_elegido = input("Tiene que ser un número entero:")

            try:
                mensajes_creados[int(mensaje_elegido)].mostrar_usuarios_recibidos(usuarios_creados)
                print("\n(0.Atrás ---- 1.Crear Mensaje ---- 2.Enviar mensaje ---- 3.Lista de mensajes enviados ---- 4.Lista de mensajes recibidos ---- 5. Lista de mensajes abiertos ---- 6.Obtener estadísticas).")
            except (IndexError, KeyError):
                print("Ha ocurrido un error")
                print("\n(0.Atrás ---- 1.Crear Mensaje ---- 2.Enviar mensaje ---- 3.Lista de mensajes enviados ---- 4.Lista de mensajes recibidos ---- 5. Lista de mensajes abiertos ---- 6.Obtener estadísticas).")
            
            opcion_mensaje = input()
        
        #Listado de mensajes abiertos/leidos
        elif opcion_mensaje == '5':
            print("Seleccione el mensaje del que desea ver la lista de usuarios que han abierto el mensaje: ")
            #Mejor poner el "SE" inicial arriba
            SE = Sistema_Entrega_Mensajes()
            SE.mostrar_mensajes(mensajes_creados)
            mensaje_elegido = input("Tiene que ser un número entero:")

            try:
                mensajes_creados[int(mensaje_elegido)].mostrar_usuarios_leidos(usuarios_creados)
                print("\n(0.Atrás ---- 1.Crear Mensaje ---- 2.Enviar mensaje ---- 3.Lista de mensajes enviados ---- 4.Lista de mensajes recibidos ---- 5. Lista de mensajes abiertos ---- 6.Obtener estadísticas).")
            except (IndexError, KeyError):
                print("Ha ocurrido un error")
                print("\n(0.Atrás ---- 1.Crear Mensaje ---- 2.Enviar mensaje ---- 3.Lista de mensajes enviados ---- 4.Lista de mensajes recibidos ---- 5. Lista de mensajes abiertos ---- 6.Obtener estadísticas).")
            
            opcion_mensaje = input()
        
        #Estadísticas de recibidos y apertura
        elif opcion_mensaje == '6':
            print("Seleccione el mensaje del que desea ver las estadísticas: ")
            #Mejor poner el "SE" inicial arriba
            SE = Sistema_Entrega_Mensajes()
            SE.mostrar_mensajes(mensajes_creados)
            mensaje_elegido = input("Tiene que ser un número entero:")

            try:
                mensajes_creados[int(mensaje_elegido)].estadisticas_apertura(usuarios_creados)
                mensajes_creados[int(mensaje_elegido)].estadisticas_recepcion(usuarios_creados)
                print("\n(0.Atrás ---- 1.Crear Mensaje ---- 2.Enviar mensaje ---- 3.Lista de mensajes enviados ---- 4.Lista de mensajes recibidos ---- 5. Lista de mensajes abiertos ---- 6.Obtener estadísticas).")
            except (IndexError, KeyError):
                print("Ha ocurrido un error")
                print("\n(0.Atrás ---- 1.Crear Mensaje ---- 2.Enviar mensaje ---- 3.Lista de mensajes enviados ---- 4.Lista de mensajes recibidos ---- 5. Lista de mensajes abiertos ---- 6.Obtener estadísticas).")
            
            opcion_mensaje = input()

        else:
            print("Incorrecto, vuelve a introducir una opción:\n(0.Atrás ---- 1.Crear Mensaje ---- 2.Enviar mensaje ---- 3.Lista de mensajes enviados ---- 4.Lista de mensajes recibidos ---- 5. Lista de mensajes abiertos ---- 6.Obtener estadísticas)")
            opcion_mensaje = input()
    inicio()


def mil_usuarios(usuarios):
    
    SE = Sistema_Entrega_Mensajes()

    print("Introduce el texto del mensaje")
    mensaje = input("Nombre del Mensaje:")

    mensajes_creados.append(Mensaje_Broadcast(mensaje))

    print("Introduce la cantidad de usuarios que desea crear")
    cantidad = int(input("Tiene que ser un número"))

    for x in range(cantidad):
        usuarios_creados[str(x)] = Usuario(x) 

    SE.registro_usuarios(usuarios_creados)
    print("Enviando mensaje...")
    SE.anyadir_mensajes(usuarios_creados, mensajes_creados[0])
    
    pass



mil_usuarios(usuarios_creados)

inicio()
# Out:
# Introduce el texto del mensaje
# Introduce la cantidad de usuarios que desea crear
# Enviando mensaje...
# Introduce una opción:
# (0.Salir ---- 1.Usuarios ---- 2.Mensajes)
# ¡¡Bienvenido a los mensajes!!, ¿Qué desea hacer?...
# (0.Atrás ---- 1.Crear Mensaje ---- 2.Enviar mensaje ---- 3.Lista de mensajes enviados ---- 4.Lista de mensajes recibidos ---- 5. Lista de mensajes abiertos ---- 6.Obtener estadísticas.)
# Seleccione el mensaje del que desea ver las estadísticas:
# (0) Broadcast
#
# (1000/0) El porcentaje de apertura del mensaje Broadcast es 0.0%
# (1000/797) El porcentaje de recepcion del mensaje Broadcast es 79.7%
#
# (0.Atrás ---- 1.Crear Mensaje ---- 2.Enviar mensaje ---- 3.Lista de mensajes enviados ---- 4.Lista de mensajes recibidos ---- 5. Lista de mensajes abiertos ---- 6.Obtener estadísticas).
# Introduce una opción:
# (0.Salir ---- 1.Usuarios ---- 2.Mensajes)

# %%
#MENSAJES INDIVIDUALIZADOS
import uuid
import random

listado_usuarios = []
usuarios_creados = {}
mensajes_creados = []

class Usuario:    
    def __init__(self, nombre):
        self.nombre = nombre
        self.__id = ""
        self.bandeja = []

    def set_id(self, id):
        self.__id = id

    def get_id(self):
        return self.__id

    def set_bandeja(self, mensajes):
        self.bandeja.append(mensajes)

    def get_bandeja(self):
        return self.bandeja

    def mostrar_mensaje(self):
        if len(self.bandeja) == 0:
            print("No se han encontrado mensajes en este usuario aún.")
        for b in range(len(self.bandeja)):
            if self.bandeja[b]['recibido']:
                if self.bandeja[b]['leido']:
                    print(f"({b}) {self.bandeja[b]['mensaje'].cuerpo} ya ha sido leído.")
                else:
                    print(f"({b}) {self.bandeja[b]['mensaje'].cuerpo}.")

    def marcar_leido(self, numero):
        if self.bandeja[numero]['recibido']:
            self.bandeja[numero]['leido'] = True




class Mensaje:
    def __init__(self, cuerpo):
        self.cuerpo = cuerpo
        self.__id = ""

    def set_id(self, id):
        self.__id = id

    def get_id(self):
        return self.__id

    def mostrar_usuarios_enviados(self, listado):
        for usuarios in listado:
            for mensaje in listado[usuarios].bandeja:
                if mensaje['mensaje'].cuerpo == self.cuerpo:
                    print(f"El mensaje {mensaje['mensaje'].cuerpo} ha sido enviado a {listado[usuarios].nombre}")
        pass

    #Comprobar usuarios leídos manera corta, cambiar nombre de función
    def mostrar_usuarios_leidos(self, listado):
        for usuarios in listado:
            for mensaje in listado[usuarios].bandeja:
                if mensaje['recibido']:
                    if mensaje['leido'] == True and mensaje['mensaje'].cuerpo == self.cuerpo:
                        print(f"El mensaje {mensaje['mensaje'].cuerpo} ha sido leído por {listado[usuarios].nombre}")
        pass

    def mostrar_usuarios_recibidos(self, listado):
        for usuarios in listado:
            for mensaje in listado[usuarios].bandeja:
                if mensaje['recibido'] == True and mensaje['mensaje'].cuerpo == self.cuerpo:
                    print(f"El mensaje {mensaje['mensaje'].cuerpo} ha sido recibido por el usuario {listado[usuarios].nombre}")

    def estadisticas_apertura(self, listado):
        total = 0
        contador = 0
        for usuarios in listado:
            for mensaje in listado[usuarios].bandeja:
                if mensaje['mensaje'].cuerpo == self.cuerpo:
                    total += 1
                if mensaje['leido'] == True and mensaje['mensaje'].cuerpo == self.cuerpo:
                    contador +=1
        print(f'({total}/{contador}) El porcentaje de apertura del mensaje {self.cuerpo} es {str(round((100 * contador)/total,2))}%')    

    def estadisticas_recepcion(self, listado):
        total = 0
        contador = 0
        for usuarios in listado:
            for mensaje in listado[usuarios].bandeja:
                if mensaje['mensaje'].cuerpo == self.cuerpo:
                    total += 1
                if mensaje['recibido'] == True and mensaje['mensaje'].cuerpo == self.cuerpo:
                    contador +=1
        print(f'({total}/{contador}) El porcentaje de recepcion del mensaje {self.cuerpo} es {str(round((100 * contador)/total,2))}%')



class Sistema_Entrega_Mensajes:

    def mostrar_mensajes(self, mensajes):
        for i in range(len(mensajes)):
            print(f'({i}) {mensajes[i].cuerpo}\n')

    def registro_usuarios(self, usuarios):
        for usuario in usuarios:
            usuarios[usuario].set_id(uuid.uuid1())
            
    def anyadir_mensajes(self, usuario, mensaje):
        mensaje.set_id(uuid.uuid1())
        mensajes = {}
        mensajes['mensaje'] = mensaje

        #Para que un mensaje tenga la posibilidad de no recibirse
        if random.randint(1, 10) > 8:
            mensajes['recibido'] = False
        else:
            mensajes['recibido'] = True

        mensajes['leido'] = False
        usuario.bandeja.append(mensajes)


def menu_principal():
    print("Introduce una opción:\n(0.Salir ---- 1.Usuarios ---- 2.Mensajes)")
    opcion = input()
    return opcion

def menu_usuarios():
    print("Introduce una opción:\n(0.Salir ---- 1.Crear Usuario ---- 2.Mostrar Bandeja de Entrada ---- 3.Marcar Leído)")
    opcion = input()
    return opcion




def inicio():
    print("Introduce una opción:\n(0.Salir ---- 1.Usuarios ---- 2.Mensajes)")
    opcion1 = input()
    while opcion1 != '0':
        if opcion1 == '1':
            usuario()
        elif opcion1 == '2':
            mensaje()
        else:
            print("Incorrecto, vuelve a introducir una opción:\n(0.Salir ---- 1.Usuarios ---- 2.Mensajes)")
            opcion1 = input()
        break

def usuario():
    print("¡¡Bienvenido a los usuarios!!, ¿Qué desea hacer?...\n(0.Atrás ---- 1.Crear Usuario ---- 2.Mostrar Bandeja de Entrada ---- 3.Marcar Leído)")
    opcion_usuario = input()
    while opcion_usuario != '0':

        #Crear Usuario
        if opcion_usuario == '1':
            print("Introduce el nombre de usuario: ")
            nombre_usuario = input("Nombre: ")
            print("Creando usuarios, esto puede tardar un tiempo...")
            usuarios_creados[nombre_usuario] = Usuario(nombre_usuario)
            print(f'Bienvenido {usuarios_creados[nombre_usuario].nombre}!!')
            print("Usuario creado correctamente\n(0.Atrás ---- 1.Crear Usuario ---- 2.Mostrar Bandeja de Entrada ---- 3.Marcar Leído).")
            opcion_usuario = input()

        #Mostrar Bandeja de Entrada
        elif opcion_usuario == '2':
            print("Introduce el nombre de usuario del que quieres ver la bandeja de entrada: ")
            nombre_usuario = input("Nombre: ")
            print("Mostrando la bandeja de entrada...")
            try:
                usuarios_creados[nombre_usuario].mostrar_mensaje()
            except KeyError:
                print("No se ha encontrado el usuario.")
            print("\n(0.Atrás ---- 1.Crear Usuario ---- 2.Mostrar Bandeja de Entrada ---- 3.Marcar Leído).")
            opcion_usuario = input()

        #Marcar leído
        elif opcion_usuario == '3':
            print("Introduce un nombre de usuario")
            nombre_usuario = input("Nombre: ")

            try:
                usuarios_creados[nombre_usuario].mostrar_mensaje()

                try:
                    print("Introduce un mensaje que quieras marcar como leído: ")          
                    mensaje_elegido = input("Tiene que ser un número entero:")

                    usuarios_creados[nombre_usuario].marcar_leido(int(mensaje_elegido))
                    print("Mensaje marcado como leído correctamente\n(0.Atrás ---- 1.Crear Usuario ---- 2.Mostrar Bandeja de Entrada ---- 3.Marcar Leído).")
                except IndexError:
                    print("No se ha encontrado el mensaje")
            except KeyError:
                print("No se ha encontrado el usuario.")
                print("Ha ocurrido un error\n(0.Atrás ---- 1.Crear Usuario ---- 2.Mostrar Bandeja de Entrada ---- 3.Marcar Leído).")
            opcion_usuario = input()
            
        else:
            print("Incorrecto, vuelve a introducir una opción:\n(0.Atrás ---- 1.Crear Usuario ---- 2.Mostrar Bandeja de Entrada ---- 3.Marcar Leído)")
            opcion_usuario = input()
    inicio()

def mensaje():
    print("¡¡Bienvenido a los mensajes!!, ¿Qué desea hacer?...\n(0.Atrás ---- 1.Crear Mensaje ---- 2.Enviar mensaje ---- 3.Lista de mensajes enviados ---- 4.Lista de mensajes recibidos ---- 5. Lista de mensajes abiertos ---- 6.Obtener estadísticas)")
    opcion_mensaje = input()
    while opcion_mensaje != '0':
        #Crear mensaje
        if opcion_mensaje == '1':
            print("Introduce el mensaje que desea escribir: ")
            nombre_mensaje = input("Mensaje: ")
            mensajes_creados.append(Mensaje(nombre_mensaje))

            print("Mensaje escrito correctamente\n(0.Atrás ---- 1.Crear Mensaje ---- 2.Enviar mensaje ---- 3.Lista de mensajes enviados ---- 4.Lista de mensajes recibidos ---- 5. Lista de mensajes abiertos ---- 6.Obtener estadísticas).")
            opcion_mensaje = input()
        
        #Enviar mensaje
        elif opcion_mensaje == '2':
            print("Seleccione el mensaje que desea enviar: ")
            SE = Sistema_Entrega_Mensajes()
            SE.mostrar_mensajes(mensajes_creados)
            mensaje_elegido = input("Tiene que ser un número entero:")

            print("Seleccione el receptor")
            nombre_receptor = input()

            print("Registrando Usuario en la terminal...")
            SE.registro_usuarios(usuarios_creados)

            print("Enviando mensaje...")
            try:
                SE.anyadir_mensajes(usuarios_creados[nombre_receptor], mensajes_creados[int(mensaje_elegido)])
                print("¡¡Mensaje enviado correctamente!!\n(0.Atrás ---- 1.Crear Mensaje ---- 2.Enviar mensaje ---- 3.Lista de mensajes enviados ---- 4.Lista de mensajes recibidos ---- 5. Lista de mensajes abiertos ---- 6.Obtener estadísticas).")
            except (IndexError, KeyError):
                print("Ha ocurrido un error")
                print("\n(0.Atrás ---- 1.Crear Mensaje ---- 2.Enviar mensaje ---- 3.Lista de mensajes enviados ---- 4.Lista de mensajes recibidos ---- 5. Lista de mensajes abiertos ---- 6.Obtener estadísticas).")
            opcion_mensaje = input()
        
        
        #Listado de mensajes enviados
        elif opcion_mensaje == '3':
            print("Seleccione el mensaje del que desea ver la lista de usuarios a los que se les ha enviado: ")
            #Mejor poner el "SE" inicial arriba
            SE = Sistema_Entrega_Mensajes()
            SE.mostrar_mensajes(mensajes_creados)
            mensaje_elegido = input("Tiene que ser un número entero:")

            try:
                mensajes_creados[int(mensaje_elegido)].mostrar_usuarios_enviados(usuarios_creados)
                print("\n(0.Atrás ---- 1.Crear Mensaje ---- 2.Enviar mensaje ---- 3.Lista de mensajes enviados ---- 4.Lista de mensajes recibidos ---- 5. Lista de mensajes abiertos ---- 6.Obtener estadísticas).")
            except (IndexError, KeyError):
                print("Ha ocurrido un error")
                print("\n(0.Atrás ---- 1.Crear Mensaje ---- 2.Enviar mensaje ---- 3.Lista de mensajes enviados ---- 4.Lista de mensajes recibidos ---- 5. Lista de mensajes abiertos ---- 6.Obtener estadísticas).")
            opcion_mensaje = input()
        
        #Listado de mensajes recibidos
        elif opcion_mensaje == '4':
            print("Seleccione el mensaje del que desea ver la lista de usuarios que han recibido el mensaje: ")
            #Mejor poner el "SE" inicial arriba
            SE = Sistema_Entrega_Mensajes()
            SE.mostrar_mensajes(mensajes_creados)
            mensaje_elegido = input("Tiene que ser un número entero:")

            try:
                mensajes_creados[int(mensaje_elegido)].mostrar_usuarios_recibidos(usuarios_creados)
                print("\n(0.Atrás ---- 1.Crear Mensaje ---- 2.Enviar mensaje ---- 3.Lista de mensajes enviados ---- 4.Lista de mensajes recibidos ---- 5. Lista de mensajes abiertos ---- 6.Obtener estadísticas).")
            except (IndexError, KeyError):
                print("Ha ocurrido un error")
                print("\n(0.Atrás ---- 1.Crear Mensaje ---- 2.Enviar mensaje ---- 3.Lista de mensajes enviados ---- 4.Lista de mensajes recibidos ---- 5. Lista de mensajes abiertos ---- 6.Obtener estadísticas).")
            opcion_mensaje = input()
            
        
        #Listado de mensajes abiertos/leidos
        elif opcion_mensaje == '5':
            print("Seleccione el mensaje del que desea ver la lista de usuarios que han abierto el mensaje: ")
            #Mejor poner el "SE" inicial arriba
            SE = Sistema_Entrega_Mensajes()
            SE.mostrar_mensajes(mensajes_creados)
            mensaje_elegido = input("Tiene que ser un número entero:")

            try:
                mensajes_creados[int(mensaje_elegido)].mostrar_usuarios_leidos(usuarios_creados)
                print("\n(0.Atrás ---- 1.Crear Mensaje ---- 2.Enviar mensaje ---- 3.Lista de mensajes enviados ---- 4.Lista de mensajes recibidos ---- 5. Lista de mensajes abiertos ---- 6.Obtener estadísticas).")
            except (IndexError, KeyError):
                print("Ha ocurrido un error")
                print("\n(0.Atrás ---- 1.Crear Mensaje ---- 2.Enviar mensaje ---- 3.Lista de mensajes enviados ---- 4.Lista de mensajes recibidos ---- 5. Lista de mensajes abiertos ---- 6.Obtener estadísticas).")
            opcion_mensaje = input()
            
        
        #Estadísticas de recibidos y apertura
        elif opcion_mensaje == '6':
            print("Seleccione el mensaje del que desea ver las estadísticas: ")
            #Mejor poner el "SE" inicial arriba
            SE = Sistema_Entrega_Mensajes()
            SE.mostrar_mensajes(mensajes_creados)
            mensaje_elegido = input("Tiene que ser un número entero:")

            try:
                mensajes_creados[int(mensaje_elegido)].estadisticas_apertura(usuarios_creados)
                mensajes_creados[int(mensaje_elegido)].estadisticas_recepcion(usuarios_creados)
                print("\n(0.Atrás ---- 1.Crear Mensaje ---- 2.Enviar mensaje ---- 3.Lista de mensajes enviados ---- 4.Lista de mensajes recibidos ---- 5. Lista de mensajes abiertos ---- 6.Obtener estadísticas).")
            except (IndexError, KeyError):
                print("Ha ocurrido un error")
                print("\n(0.Atrás ---- 1.Crear Mensaje ---- 2.Enviar mensaje ---- 3.Lista de mensajes enviados ---- 4.Lista de mensajes recibidos ---- 5. Lista de mensajes abiertos ---- 6.Obtener estadísticas).")
            opcion_mensaje = input()
            

        else:
            print("Incorrecto, vuelve a introducir una opción:\n(0.Atrás ---- 1.Crear Mensaje ---- 2.Enviar mensaje ---- 3.Lista de mensajes enviados ---- 4.Lista de mensajes recibidos ---- 5. Lista de mensajes abiertos ---- 6.Obtener estadísticas).")
            opcion_mensaje = input()
    inicio()

#Pruebas
"""mensajes_creados.append(Mensaje("Mensaje Pepe2"))
mensajes_creados.append(Mensaje("Mensaje Pepe"))
usuarios_creados['Pepe'] = Usuario('Pepe')
usuarios_creados['Rodolfo'] = Usuario('Rodolfo')
SE = Sistema_Entrega_Mensajes()

SE.anyadir_mensajes(usuarios_creados['Pepe'], mensajes_creados[0])
SE.anyadir_mensajes(usuarios_creados['Rodolfo'], mensajes_creados[0])
SE.anyadir_mensajes(usuarios_creados['Pepe'], mensajes_creados[1])

usuarios_creados['Pepe'].marcar_leido(0)

mensajes_creados[0].mostrar_usuarios_enviados(usuarios_creados)
mensajes_creados[0].mostrar_usuarios_leidos(usuarios_creados)
mensajes_creados[0].mostrar_usuarios_recibidos(usuarios_creados)

mensajes_creados[1].mostrar_usuarios_enviados(usuarios_creados)
mensajes_creados[1].mostrar_usuarios_leidos(usuarios_creados)
mensajes_creados[1].mostrar_usuarios_recibidos(usuarios_creados)"""

inicio()
# Out:
# Introduce una opción:
# (0.Salir ---- 1.Usuarios ---- 2.Mensajes)
# ¡¡Bienvenido a los usuarios!!, ¿Qué desea hacer?...
# (0.Atrás ---- 1.Crear Usuario ---- 2.Mostrar Bandeja de Entrada ---- 3.Marcar Leído)
# Introduce el nombre de usuario del que quieres ver la bandeja de entrada:
# Mostrando la bandeja de entrada...
# No se ha encontrado el usuario.
#
# (0.Atrás ---- 1.Crear Usuario ---- 2.Mostrar Bandeja de Entrada ---- 3.Marcar Leído).
# Introduce el nombre de usuario:
# Creando usuarios, esto puede tardar un tiempo...
# Bienvenido Dani!!
# Usuario creado correctamente
# (0.Atrás ---- 1.Crear Usuario ---- 2.Mostrar Bandeja de Entrada ---- 3.Marcar Leído).
# Introduce una opción:
# (0.Salir ---- 1.Usuarios ---- 2.Mensajes)
# ¡¡Bienvenido a los mensajes!!, ¿Qué desea hacer?...
# (0.Atrás ---- 1.Crear Mensaje ---- 2.Enviar mensaje ---- 3.Lista de mensajes enviados ---- 4.Lista de mensajes recibidos ---- 5. Lista de mensajes abiertos ---- 6.Obtener estadísticas)
# Introduce el mensaje que desea escribir:
# Mensaje escrito correctamente
# (0.Atrás ---- 1.Crear Mensaje ---- 2.Enviar mensaje ---- 3.Lista de mensajes enviados ---- 4.Lista de mensajes recibidos ---- 5. Lista de mensajes abiertos ---- 6.Obtener estadísticas).
# Seleccione el mensaje que desea enviar:
# (0) Buenos días dani
#
# Seleccione el receptor
# Registrando Usuario en la terminal...
# Enviando mensaje...
# Ha ocurrido un error
#
# (0.Atrás ---- 1.Crear Mensaje ---- 2.Enviar mensaje ---- 3.Lista de mensajes enviados ---- 4.Lista de mensajes recibidos ---- 5. Lista de mensajes abiertos ---- 6.Obtener estadísticas).
# Seleccione el mensaje que desea enviar:
# (0) Buenos días dani
#
# Seleccione el receptor
# Registrando Usuario en la terminal...
# Enviando mensaje...
# ¡¡Mensaje enviado correctamente!!
# (0.Atrás ---- 1.Crear Mensaje ---- 2.Enviar mensaje ---- 3.Lista de mensajes enviados ---- 4.Lista de mensajes recibidos ---- 5. Lista de mensajes abiertos ---- 6.Obtener estadísticas).
# Seleccione el mensaje del que desea ver la lista de usuarios a los que se les ha enviado:
# (0) Buenos días dani
#
# El mensaje Buenos días dani ha sido enviado a Dani
#
# (0.Atrás ---- 1.Crear Mensaje ---- 2.Enviar mensaje ---- 3.Lista de mensajes enviados ---- 4.Lista de mensajes recibidos ---- 5. Lista de mensajes abiertos ---- 6.Obtener estadísticas).
# Seleccione el mensaje del que desea ver la lista de usuarios que han recibido el mensaje:
# (0) Buenos días dani
#
# El mensaje Buenos días dani ha sido recibido por el usuario Dani
#
# (0.Atrás ---- 1.Crear Mensaje ---- 2.Enviar mensaje ---- 3.Lista de mensajes enviados ---- 4.Lista de mensajes recibidos ---- 5. Lista de mensajes abiertos ---- 6.Obtener estadísticas).
# Introduce una opción:
# (0.Salir ---- 1.Usuarios ---- 2.Mensajes)
# ¡¡Bienvenido a los usuarios!!, ¿Qué desea hacer?...
# (0.Atrás ---- 1.Crear Usuario ---- 2.Mostrar Bandeja de Entrada ---- 3.Marcar Leído)
# Introduce el nombre de usuario del que quieres ver la bandeja de entrada:
# Mostrando la bandeja de entrada...
# (0) Buenos días dani.
#
# (0.Atrás ---- 1.Crear Usuario ---- 2.Mostrar Bandeja de Entrada ---- 3.Marcar Leído).
# Introduce un nombre de usuario
# (0) Buenos días dani.
# Introduce un mensaje que quieras marcar como leído:
# Mensaje marcado como leído correctamente
# (0.Atrás ---- 1.Crear Usuario ---- 2.Mostrar Bandeja de Entrada ---- 3.Marcar Leído).
# Introduce una opción:
# (0.Salir ---- 1.Usuarios ---- 2.Mensajes)
# ¡¡Bienvenido a los mensajes!!, ¿Qué desea hacer?...
# (0.Atrás ---- 1.Crear Mensaje ---- 2.Enviar mensaje ---- 3.Lista de mensajes enviados ---- 4.Lista de mensajes recibidos ---- 5. Lista de mensajes abiertos ---- 6.Obtener estadísticas)
# Seleccione el mensaje del que desea ver la lista de usuarios que han abierto el mensaje:
# (0) Buenos días dani
#
# El mensaje Buenos días dani ha sido leído por Dani
#
# (0.Atrás ---- 1.Crear Mensaje ---- 2.Enviar mensaje ---- 3.Lista de mensajes enviados ---- 4.Lista de mensajes recibidos ---- 5. Lista de mensajes abiertos ---- 6.Obtener estadísticas).
# Seleccione el mensaje del que desea ver las estadísticas:
# (0) Buenos días dani
#
# (1/1) El porcentaje de apertura del mensaje Buenos días dani es 100.0%
# (1/1) El porcentaje de recepcion del mensaje Buenos días dani es 100.0%
#
# (0.Atrás ---- 1.Crear Mensaje ---- 2.Enviar mensaje ---- 3.Lista de mensajes enviados ---- 4.Lista de mensajes recibidos ---- 5. Lista de mensajes abiertos ---- 6.Obtener estadísticas).
# Introduce una opción:
# (0.Salir ---- 1.Usuarios ---- 2.Mensajes)

# %%
import uuid
import random
import Usuario
import Mensaje
import Sistema_Entrega_Mensajes

listado_usuarios = []
usuarios_creados = {}
mensajes_creados = []

def menu_principal():
    print("Introduce una opción:\n(0.Salir ---- 1.Usuarios ---- 2.Mensajes)")
    opcion = input()
    return opcion

def menu_usuarios():
    print("Introduce una opción:\n(0.Salir ---- 1.Crear Usuario ---- 2.Mostrar Bandeja de Entrada ---- 3.Marcar Leído)")
    opcion = input()
    return opcion




def inicio():
    print("Introduce una opción:\n(0.Salir ---- 1.Usuarios ---- 2.Mensajes)")
    opcion1 = input()
    while opcion1 != '0':
        if opcion1 == '1':
            usuario()
        elif opcion1 == '2':
            mensaje()
        else:
            print("Incorrecto, vuelve a introducir una opción:\n(0.Salir ---- 1.Usuarios ---- 2.Mensajes)")
            opcion1 = input()
        break

def usuario():
    print("¡¡Bienvenido a los usuarios!!, ¿Qué desea hacer?...\n(0.Atrás ---- 1.Crear Usuario ---- 2.Mostrar Bandeja de Entrada ---- 3.Marcar Leído)")
    opcion_usuario = input()
    while opcion_usuario != '0':

        #Crear Usuario
        if opcion_usuario == '1':
            print("Introduce el nombre de usuario: ")
            nombre_usuario = input("Nombre: ")
            print("Creando usuarios, esto puede tardar un tiempo...")
            usuarios_creados[nombre_usuario] = Usuario(nombre_usuario)
            print(f'Bienvenido {usuarios_creados[nombre_usuario].nombre}!!')
            print("Usuario creado correctamente\n(0.Atrás ---- 1.Crear Usuario ---- 2.Mostrar Bandeja de Entrada ---- 3.Marcar Leído).")
            opcion_usuario = input()

        #Mostrar Bandeja de Entrada
        elif opcion_usuario == '2':
            print("Introduce el nombre de usuario del que quieres ver la bandeja de entrada: ")
            nombre_usuario = input("Nombre: ")
            print("Mostrando la bandeja de entrada...")
            try:
                usuarios_creados[nombre_usuario].mostrar_mensaje()
            except KeyError:
                print("No se ha encontrado el usuario.")
            print("\n(0.Atrás ---- 1.Crear Usuario ---- 2.Mostrar Bandeja de Entrada ---- 3.Marcar Leído).")
            opcion_usuario = input()

        #Marcar leído
        elif opcion_usuario == '3':
            print("Introduce un nombre de usuario")
            nombre_usuario = input("Nombre: ")

            try:
                usuarios_creados[nombre_usuario].mostrar_mensaje()

                try:
                    print("Introduce un mensaje que quieras marcar como leído: ")          
                    mensaje_elegido = input("Tiene que ser un número entero:")

                    usuarios_creados[nombre_usuario].marcar_leido(int(mensaje_elegido))
                    print("Mensaje marcado como leído correctamente\n(0.Atrás ---- 1.Crear Usuario ---- 2.Mostrar Bandeja de Entrada ---- 3.Marcar Leído).")
                except IndexError:
                    print("No se ha encontrado el mensaje")
            except KeyError:
                print("No se ha encontrado el usuario.")
                print("Ha ocurrido un error\n(0.Atrás ---- 1.Crear Usuario ---- 2.Mostrar Bandeja de Entrada ---- 3.Marcar Leído).")
            opcion_usuario = input()
            
        else:
            print("Incorrecto, vuelve a introducir una opción:\n(0.Atrás ---- 1.Crear Usuario ---- 2.Mostrar Bandeja de Entrada ---- 3.Marcar Leído)")
            opcion_usuario = input()
    inicio()

def mensaje():
    print("¡¡Bienvenido a los mensajes!!, ¿Qué desea hacer?...\n(0.Atrás ---- 1.Crear Mensaje ---- 2.Enviar mensaje ---- 3.Lista de mensajes enviados ---- 4.Lista de mensajes recibidos ---- 5. Lista de mensajes abiertos ---- 6.Obtener estadísticas)")
    opcion_mensaje = input()
    while opcion_mensaje != '0':
        #Crear mensaje
        if opcion_mensaje == '1':
            print("Introduce el mensaje que desea escribir: ")
            nombre_mensaje = input("Mensaje: ")
            mensajes_creados.append(Mensaje(nombre_mensaje))

            print("Mensaje escrito correctamente\n(0.Atrás ---- 1.Crear Mensaje ---- 2.Enviar mensaje ---- 3.Lista de mensajes enviados ---- 4.Lista de mensajes recibidos ---- 5. Lista de mensajes abiertos ---- 6.Obtener estadísticas).")
            opcion_mensaje = input()
        
        #Enviar mensaje
        elif opcion_mensaje == '2':
            print("Seleccione el mensaje que desea enviar: ")
            SE = Sistema_Entrega_Mensajes()
            SE.mostrar_mensajes(mensajes_creados)
            mensaje_elegido = input("Tiene que ser un número entero:")

            print("Seleccione el receptor")
            nombre_receptor = input()

            print("Registrando Usuario en la terminal...")
            SE.registro_usuarios(usuarios_creados)

            print("Enviando mensaje...")
            try:
                SE.anyadir_mensajes(usuarios_creados[nombre_receptor], mensajes_creados[int(mensaje_elegido)])
                print("¡¡Mensaje enviado correctamente!!\n(0.Atrás ---- 1.Crear Mensaje ---- 2.Enviar mensaje ---- 3.Lista de mensajes enviados ---- 4.Lista de mensajes recibidos ---- 5. Lista de mensajes abiertos ---- 6.Obtener estadísticas).")
            except (IndexError, KeyError):
                print("Ha ocurrido un error")
                print("\n(0.Atrás ---- 1.Crear Mensaje ---- 2.Enviar mensaje ---- 3.Lista de mensajes enviados ---- 4.Lista de mensajes recibidos ---- 5. Lista de mensajes abiertos ---- 6.Obtener estadísticas).")
            opcion_mensaje = input()
        
        
        #Listado de mensajes enviados
        elif opcion_mensaje == '3':
            print("Seleccione el mensaje del que desea ver la lista de usuarios a los que se les ha enviado: ")
            #Mejor poner el "SE" inicial arriba
            SE = Sistema_Entrega_Mensajes()
            SE.mostrar_mensajes(mensajes_creados)
            mensaje_elegido = input("Tiene que ser un número entero:")

            try:
                mensajes_creados[int(mensaje_elegido)].mostrar_usuarios_enviados(usuarios_creados)
                print("\n(0.Atrás ---- 1.Crear Mensaje ---- 2.Enviar mensaje ---- 3.Lista de mensajes enviados ---- 4.Lista de mensajes recibidos ---- 5. Lista de mensajes abiertos ---- 6.Obtener estadísticas).")
            except (IndexError, KeyError):
                print("Ha ocurrido un error")
                print("\n(0.Atrás ---- 1.Crear Mensaje ---- 2.Enviar mensaje ---- 3.Lista de mensajes enviados ---- 4.Lista de mensajes recibidos ---- 5. Lista de mensajes abiertos ---- 6.Obtener estadísticas).")
            opcion_mensaje = input()
        
        #Listado de mensajes recibidos
        elif opcion_mensaje == '4':
            print("Seleccione el mensaje del que desea ver la lista de usuarios que han recibido el mensaje: ")
            #Mejor poner el "SE" inicial arriba
            SE = Sistema_Entrega_Mensajes()
            SE.mostrar_mensajes(mensajes_creados)
            mensaje_elegido = input("Tiene que ser un número entero:")

            try:
                mensajes_creados[int(mensaje_elegido)].mostrar_usuarios_recibidos(usuarios_creados)
                print("\n(0.Atrás ---- 1.Crear Mensaje ---- 2.Enviar mensaje ---- 3.Lista de mensajes enviados ---- 4.Lista de mensajes recibidos ---- 5. Lista de mensajes abiertos ---- 6.Obtener estadísticas).")
            except (IndexError, KeyError):
                print("Ha ocurrido un error")
                print("\n(0.Atrás ---- 1.Crear Mensaje ---- 2.Enviar mensaje ---- 3.Lista de mensajes enviados ---- 4.Lista de mensajes recibidos ---- 5. Lista de mensajes abiertos ---- 6.Obtener estadísticas).")
            opcion_mensaje = input()
            
        
        #Listado de mensajes abiertos/leidos
        elif opcion_mensaje == '5':
            print("Seleccione el mensaje del que desea ver la lista de usuarios que han abierto el mensaje: ")
            #Mejor poner el "SE" inicial arriba
            SE = Sistema_Entrega_Mensajes()
            SE.mostrar_mensajes(mensajes_creados)
            mensaje_elegido = input("Tiene que ser un número entero:")

            try:
                mensajes_creados[int(mensaje_elegido)].mostrar_usuarios_leidos(usuarios_creados)
                print("\n(0.Atrás ---- 1.Crear Mensaje ---- 2.Enviar mensaje ---- 3.Lista de mensajes enviados ---- 4.Lista de mensajes recibidos ---- 5. Lista de mensajes abiertos ---- 6.Obtener estadísticas).")
            except (IndexError, KeyError):
                print("Ha ocurrido un error")
                print("\n(0.Atrás ---- 1.Crear Mensaje ---- 2.Enviar mensaje ---- 3.Lista de mensajes enviados ---- 4.Lista de mensajes recibidos ---- 5. Lista de mensajes abiertos ---- 6.Obtener estadísticas).")
            opcion_mensaje = input()
            
        
        #Estadísticas de recibidos y apertura
        elif opcion_mensaje == '6':
            print("Seleccione el mensaje del que desea ver las estadísticas: ")
            #Mejor poner el "SE" inicial arriba
            SE = Sistema_Entrega_Mensajes()
            SE.mostrar_mensajes(mensajes_creados)
            mensaje_elegido = input("Tiene que ser un número entero:")

            try:
                mensajes_creados[int(mensaje_elegido)].estadisticas_apertura(usuarios_creados)
                mensajes_creados[int(mensaje_elegido)].estadisticas_recepcion(usuarios_creados)
                print("\n(0.Atrás ---- 1.Crear Mensaje ---- 2.Enviar mensaje ---- 3.Lista de mensajes enviados ---- 4.Lista de mensajes recibidos ---- 5. Lista de mensajes abiertos ---- 6.Obtener estadísticas).")
            except (IndexError, KeyError):
                print("Ha ocurrido un error")
                print("\n(0.Atrás ---- 1.Crear Mensaje ---- 2.Enviar mensaje ---- 3.Lista de mensajes enviados ---- 4.Lista de mensajes recibidos ---- 5. Lista de mensajes abiertos ---- 6.Obtener estadísticas).")
            opcion_mensaje = input()
            

        else:
            print("Incorrecto, vuelve a introducir una opción:\n(0.Atrás ---- 1.Crear Mensaje ---- 2.Enviar mensaje ---- 3.Lista de mensajes enviados ---- 4.Lista de mensajes recibidos ---- 5. Lista de mensajes abiertos ---- 6.Obtener estadísticas).")
            opcion_mensaje = input()
    inicio()

#Pruebas
mensajes_creados.append(Mensaje("Mensaje Pepe2"))
mensajes_creados.append(Mensaje("Mensaje Pepe"))
usuarios_creados['Pepe'] = Usuario('Pepe')
usuarios_creados['Rodolfo'] = Usuario('Rodolfo')
SE = Sistema_Entrega_Mensajes()

SE.anyadir_mensajes(usuarios_creados['Pepe'], mensajes_creados[0])
SE.anyadir_mensajes(usuarios_creados['Rodolfo'], mensajes_creados[0])
SE.anyadir_mensajes(usuarios_creados['Pepe'], mensajes_creados[1])

usuarios_creados['Pepe'].marcar_leido(0)

mensajes_creados[0].mostrar_usuarios_enviados(usuarios_creados)
mensajes_creados[0].mostrar_usuarios_leidos(usuarios_creados)
mensajes_creados[0].mostrar_usuarios_recibidos(usuarios_creados)

mensajes_creados[1].mostrar_usuarios_enviados(usuarios_creados)
mensajes_creados[1].mostrar_usuarios_leidos(usuarios_creados)
mensajes_creados[1].mostrar_usuarios_recibidos(usuarios_creados)

inicio()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-42-208c46ccb375> in <module>
#       1 import uuid
#       2 import random
# ----> 3 import Usuario
#       4 import Mensaje
#       5 import Sistema_Entrega_Mensajes
#
# ModuleNotFoundError: No module named 'Usuario'
